# %% [markdown]
# ## Import Necessary Libraries

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Get data

# %%
## Use below method later

## import kagglehub

# Download latest version
## path = kagglehub.dataset_download("jennyzzhu/vancouver-house-prices-for-past-20-years")

## print("Path to dataset files:", path)

# %%
## CP Start from here - Nov 4, 2025

## vncvr_housing_sales = pd.read_csv()


## vncvr_neighbourhoods = pd.read_csv()

# %% [markdown]
# ### Read data in dataframe

# %%
### vncvr_housing_data = pd.read_excel()

#Look at the first 10 rows in the dataset.
## vncvr_housing_data.head(10)
